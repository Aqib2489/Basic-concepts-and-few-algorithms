# %% [markdown]
# <span style="font-size:2em;">CIV E 779 Machine Learning for Engineers - Assignment 1</span>
#
# <span style="font-size:2em;">Instructor: Dr. Qipei (Gavin) Mei (qipei.mei@ualberta.ca)</span>
#
# <span style="font-size:2em;">Student Name: Mohammad Aqib </span>
#
# <span style="font-size:2em;">CCID: maqib </span>

# %% [markdown]
# # 1. Python Basics [10 Marks]

# %% [markdown]
# 1.1 **[5 Marks]** Create a function called check_divisibility and show the output of n=30. The function should do the following: Given an integer n, return **a list** called answer where:\
# answer[i] == "Divisible by 3 and 5" if i is divisible by 3 and 5.\
# answer[i] == "Divisible by 3" if i is divisible by 3 only.\
# answer[i] == "Divisible by 5" if i is divisible by 5 only.\
# answer[i] == i (as a string) if none of the above conditions are true.
#
# For example:
# + Input: n = 5 \
#      Output: ["1","2","Divisible by 3","4","Divisible by 5"]
#
# + Input: n = 15\
# Output: ["1","2","Divisible by 3","4","Divisible by 5","Divisible by 3","7","8","Divisible by 3","Divisible by 5","11","Divisible by 3","13","14","Divisible by 3 and 5"]

# %%
# Define the function check_divisibility
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.

def check_divisibility(n):
  answer=[]
  for i in range(1,n+1):
    if i%3==0 and i%5==0:
      answer.append("Divisible by 3 and 5")
    if i%3==0:
      answer.append(f"Divisible by 3")
    elif i%5==0:
      answer.append(f"Divisible by 5")
    else:
      answer.append(str(i))

  return answer

# Print check_divisibility(30)
n=30
output= check_divisibility(n)
print(output)
# Out:
# ['1', '2', 'Divisible by 3', '4', 'Divisible by 5', 'Divisible by 3', '7', '8', 'Divisible by 3', 'Divisible by 5', '11', 'Divisible by 3', '13', '14', 'Divisible by 3 and 5', 'Divisible by 3', '16', '17', 'Divisible by 3', '19', 'Divisible by 5', 'Divisible by 3', '22', '23', 'Divisible by 3', 'Divisible by 5', '26', 'Divisible by 3', '28', '29', 'Divisible by 3 and 5', 'Divisible by 3']

# %% [markdown]
# 1.2 **[5 Marks]** Please use the library matplotlib to regenerate the figure in this [link](https://www.dropbox.com/s/q192gt7i78kvgsb/Assignment%201%20Figure.jpg?dl=0) as closely as possible. You should add the exact same title, x/y labels, data ranges for x and y axes, and grid lines. You should adjust the bar width (1.5), colors (green and red) and line style (dashed line for the trendline) to match the provided figure. Don't worry about the font, font size or resolution.
#
# The data points for the figure are fomulated in the table below:
#
# Strenth |Frequency |Y value of trendline (red line)
# -----|-----|-----
# 20|0|0.25
# 22|2|1
# 24|3|3.2
# 26|6|8
# 28|11|15.7
# 30|22|24.2
# 32|30|29.2
# 34|24|27.7
# 36|16|20.6
# 38|11|12
# 40|4|5.5
# 42|2|2
# 44|1|0.6

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# Storing the data in lists
Strength = [20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44]
Frequency = [0, 2, 3, 6, 11, 22, 30, 24, 16, 11, 4, 2, 1]
Mean = [0.25, 1, 3.2, 8, 15.7, 24.2, 29.2, 27.7, 20.6, 12, 5.5, 2, 0.6]

# Creating the plot
plt.figure(figsize=(10, 6))

# Plotting the histogram as bars
plt.bar(Strength, Frequency, width=1.5, color='green')

# Overlaying the Gaussian Distribution curve
plt.plot(Strength, Mean, color='red',linestyle="--")

plt.xlabel("Strength(MPa)")
plt.ylabel("Frequency")
plt.title("Concrete Compressive Strength Distribution")

# Adjusting the x-axis and y-axis limit as shown in the provided figure.
plt.xlim(20, 45)
plt.ylim(0, 30)
plt.grid(axis='both', linestyle='-')

# Showing the plot
plt.show()

# %% [markdown]
# # 2. Matrix operations in Python [10 Marks]
#
# Given two matrices,
#
# $$A = \begin{bmatrix} 5 & 2 & 1 \\ 3 & 1 & 2 \\ 0 & 4 & 1 \end{bmatrix} $$
#
# $$B = \begin{bmatrix} 1 & -5 & 0 \\ -5 & 6 & -3 \\ 0 & -3 & 2 \end{bmatrix} $$
#
# Use the package **numpy** to do the following:

# %% [markdown]
# 2.1 **[0.5 Mark]** Create two numpy arrays to store matrices A and B

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
import numpy as np
A= np.array([
    [5,2,1],
    [3,1,2],
    [0,4,1]
           ])
B= np.array([
    [1,-5,0],
    [-5,6,-3],
    [0,-3,2]
   ])

# %% [markdown]
# 2.2 **[0.5 Mark]** Calculate the transpose of A

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.

# Don't delete these two comments so that it would be easier for me to locate your answers.
C= A.T
print("Transpose of A is:\n", C)
# Out:
# Transpose of A is:
#  [[5 3 0]
#  [2 1 4]
#  [1 2 1]]

# %% [markdown]
# 2.3 **[0.5 Mark]** Calculate the trace of A

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
D= np.trace(A)
print("Trace of A is:",D)
# Out:
# Trace of A is: 7

# %% [markdown]
# 2.4 **[0.5 Mark]** Calculate the rank of A

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
Rank = np.linalg.matrix_rank(A)
print("Rank of A is:",Rank)
# Out:
# Rank of A is: 3

# %% [markdown]
# 2.5 **[1 Mark]** Calculate the inverse of A

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
Inverse = np.linalg.inv(A)
print("Inverse of A is:\n",Inverse)
# Out:
# Inverse of A is:
#  [[ 0.24137931 -0.06896552 -0.10344828]
#  [ 0.10344828 -0.17241379  0.24137931]
#  [-0.4137931   0.68965517  0.03448276]]

# %% [markdown]
# 2.6 **[1 Mark]** Calculate the determinant of A

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
determinant = np.linalg.det(A)
print("Determinant of A is:\n",determinant)
# Out:
# Determinant of A is:
#  -28.99999999999999

# %% [markdown]
# 2.7 **[1 Mark]** Calculate the addition of A and B

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
E= np.add(A,B)
print("Sum of A and B is:\n",E)
# Out:
# Sum of A and B is:
#  [[ 6 -3  1]
#  [-2  7 -1]
#  [ 0  1  3]]

# %% [markdown]
# 2.8 **[1 Mark]** Calculate the multiplication of A and B

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
A= np.array([
    [5,2,1],
    [3,1,2],
    [0,4,1]
           ])
B= np.array([
    [1,-5,0],
    [-5,6,-3],
    [0,-3,2]
   ])
print("Element-wise multiplication of A and B is: \n " ,np.multiply(A,B))

print("Dot product of A and B is:\n",np.dot(A,B))
# Out:
# Element-wise multiplication of A and B is:
#   [[  5 -10   0]
#  [-15   6  -6]
#  [  0 -12   2]]
# Dot product of A and B is:
#  [[ -5 -16  -4]
#  [ -2 -15   1]
#  [-20  21 -10]]

# %% [markdown]
# 2.9 **[2 Marks]** Find out whether the matrix B is a orthorgonal matrix or not

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
"""
Orthogonal matrix has a property that dot product of its transpose and matrix itself gives identity matrix.
"""
B= np.array([
    [1,-5,0],
    [-5,6,-3],
    [0,-3,2]
   ])
I = np.identity(3)
Trans_B= B.T
Multi = np.dot(B, Trans_B)
if (Multi==I).all():
  print("B is a orthoginal matrix")
else:
  print("B is not a orthogonal matrix")
# Out:
# B is not a orthogonal matrix

# %% [markdown]
# 2.10 **[2 Marks]** Find out whether the matrix B is positive definite or not. Hint: a matrix is postive definite if all the eigenvalues are positive.

# %%
# TODO: Please provide your answers here. You can add more cells for code or texts if needed.
# Don't delete these two comments so that it would be easier for me to locate your answers.
Eigen_values, Eigen_Vector = np.linalg.eig(B)
print(Eigen_values)
m=0
for i in range(len(Eigen_values)):
  if Eigen_values[i] > 0:
    m=m+1
if m==len(Eigen_values):
  print("B is a positive definite")
else:
  print("B is not a positive definite")
# Out:
# [ 9.93307783 -2.69124651  1.75816868]
# B is not a positive definite
